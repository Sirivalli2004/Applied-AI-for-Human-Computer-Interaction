# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm


data = pd.read_csv("/content/drive/MyDrive/emotion_2/fer2013(2).csv")
data.head()

labels = []
usage = []

for i in data["emotion"]:
    labels.append(i)
    
for i in data["Usage"]:
    usage.append(i)
    
print(set(labels))
print(set(usage))
# Out:
# {0, 1, 2, 3, 4, 5, 6}
# {'PrivateTest', 'Training', 'PublicTest'}

# %%
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0

for i, j, k in tqdm(zip(data["emotion"], data["pixels"], data["Usage"])):
    pixel = []
    pixels = j.split(' ')
    for m in pixels:
        value = float(m)
        pixel.append(value)
    pixel = np.array(pixel)
    img = pixel.reshape(48, 48)
    
    if k == "Training":
        if not os.path.exists("drive/MyDrive/emotion_2/train"):
            os.mkdir("drive/MyDrive/emotion_2/train")
        if i == 0:
            if not os.path.exists("drive/MyDrive/emotion_2/train/Angry"):
                os.mkdir("drive/MyDrive/emotion_2/train/Angry")
                path = "drive/MyDrive/emotion_2/train/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , img)
                count0 += 1
            else:
                path = "drive/MyDrive/emotion_2/train/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , img)
                count0 += 1    
 
        # if i == 1:
        #     if not os.path.exists("drive/MyDrive/emotion_2/train/Disgust"):
        #         os.mkdir("drive/MyDrive/emotion_2/train/Disgust")
        #         path = "drive/MyDrive/emotion_2/train/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , img)
        #         count1 += 1
        #     else:
        #         path = "drive/MyDrive/emotion_2/train/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , img)
        #         count1 += 1
        if i == 2:
            if not os.path.exists("drive/MyDrive/emotion_2/train/Fear"):
                os.mkdir("drive/MyDrive/emotion_2/train/Fear")
                path = "drive/MyDrive/emotion_2/train/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , img)
                count2 += 1
            else:
                path = "drive/MyDrive/emotion_2/train/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , img)
                count2 += 1
        if i == 3:
            if not os.path.exists("drive/MyDrive/emotion_2/train/Happy"):
                os.mkdir("drive/MyDrive/emotion_2/train/Happy")
                path = "drive/MyDrive/emotion_2/train/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , img)
                count3 += 1
            else:
                path = "drive/MyDrive/emotion_2/train/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , img)
                count3 += 1
        if i == 4:
            if not os.path.exists("drive/MyDrive/emotion_2/train/Sad"):
                os.mkdir("drive/MyDrive/emotion_2/train/Sad")
                path = "drive/MyDrive/emotion_2/train/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , img)
                count4 += 1
            else:
                path = "drive/MyDrive/emotion_2/train/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , img)
                count4 += 1
        if i == 5:
            if not os.path.exists("drive/MyDrive/emotion_2/train/Surprise"):
                os.mkdir("drive/MyDrive/emotion_2/train/Surprise")
                path = "drive/MyDrive/emotion_2/train/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , img)
                count5 += 1
            else:
                path = "drive/MyDrive/emotion_2/train/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , img)
                count5 += 1
        if i == 6:
            if not os.path.exists("drive/MyDrive/emotion_2/train/Neutral"):
                os.mkdir("drive/MyDrive/emotion_2/train/Neutral")
                path = "drive/MyDrive/emotion_2/train/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , img)
                count6 += 1
            else:
                path = "drive/MyDrive/emotion_2/train/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , img)
                count6 += 1
    else:
        if not os.path.exists("drive/MyDrive/emotion_2/validation"):
            os.mkdir("drive/MyDrive/emotion_2/validation")
        if i == 0:
            if not os.path.exists("drive/MyDrive/emotion_2/validation/Angry"):
                os.mkdir("drive/MyDrive/emotion_2/validation/Angry")
                path = "drive/MyDrive/emotion_2/validation/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , img)
                count0 += 1
            else:
                path = "drive/MyDrive/emotion_2/validation/Angry/" + str(count0) + ".jpg"
                cv2.imwrite(path , img)
                count0 += 1
        # if i == 1:
        #     if not os.path.exists("drive/MyDrive/emotion_2/validation/Disgust"):
        #         os.mkdir("drive/MyDrive/emotion_2/validation/Disgust")
        #         path = "drive/MyDrive/emotion_2/validation/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , img)
        #         count1 += 1
        #     else:
        #         path = "drive/MyDrive/emotion_2/validation/Disgust/" + str(count1) + ".jpg"
        #         cv2.imwrite(path , img)
        #         count1 += 1
        if i == 2:
            if not os.path.exists("drive/MyDrive/emotion_2/validation/Fear"):
                os.mkdir("drive/MyDrive/emotion_2/validation/Fear")
                path = "drive/MyDrive/emotion_2/validation/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , img)
                count2 += 1
            else:
                path = "drive/MyDrive/emotion_2/validation/Fear/" + str(count2) + ".jpg"
                cv2.imwrite(path , img)
                count2 += 1
        if i == 3:
            if not os.path.exists("drive/MyDrive/emotion_2/validation/Happy"):
                os.mkdir("drive/MyDrive/emotion_2/validation/Happy")
                path = "drive/MyDrive/emotion_2/validation/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , img)
                count3 += 1
            else:
                path = "drive/MyDrive/emotion_2/validation/Happy/" + str(count3) + ".jpg"
                cv2.imwrite(path , img)
                count3 += 1
        if i == 4:
            if not os.path.exists("drive/MyDrive/emotion_2/validation/Sad"):
                os.mkdir("drive/MyDrive/emotion_2/validation/Sad")
                path = "drive/MyDrive/emotion_2/validation/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , img)
                count4 += 1
            else:
                path = "drive/MyDrive/emotion_2/validation/Sad/" + str(count4) + ".jpg"
                cv2.imwrite(path , img)
                count4 += 1
        if i == 5:
            if not os.path.exists("drive/MyDrive/emotion_2/validation/Surprise"):
                os.mkdir("drive/MyDrive/emotion_2/validation/Surprise")
                path = "drive/MyDrive/emotion_2/validation/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , img)
                count5 += 1
            else:
                path = "drive/MyDrive/emotion_2/validation/Surprise/" + str(count5) + ".jpg"
                cv2.imwrite(path , img)
                count5 += 1
        if i == 6:
            if not os.path.exists("drive/MyDrive/emotion_2/validation/Neutral"):
                os.mkdir("drive/MyDrive/emotion_2/validation/Neutral")
                path = "drive/MyDrive/emotion_2/validation/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , img)
                count6 += 1
            else:
                path = "drive/MyDrive/emotion_2/validation/Neutral/" + str(count6) + ".jpg"
                cv2.imwrite(path , img)
                count6 += 1
# Out:
# 35887it [05:21, 111.62it/s]

# %%
import matplotlib.pyplot as plt
train_directory = "drive/MyDrive/emotion_2/train/"
train_dir = os.listdir(train_directory)
classes = []

for folder in train_dir:
    classes.append(folder)

train_counts = []

for folder in train_dir:
    class_path = train_directory + folder + "/"
    list_train = []
    count = 0
    for file in os.listdir(class_path):
        count +=1
    
    train_counts.append(count)
    
train_counts


plt.bar(classes, train_counts, width=0.5)
plt.title("Bar Graph of Train Data")
plt.xlabel("Classes")
plt.ylabel("Counts")


plt.scatter(classes, train_counts)
plt.plot(classes, train_counts, '-o')
plt.show()
